# %%
from cov2 import *
# Out:
# Module directory: C:\tools\Anaconda3\envs\sandbox\lib\site-packages\justpy, Application directory: C:\code\python\sandbox

# %%
df = load_remote_date('Confirmed')
df
# Out:
#                         Province/State      Lat      Long  1/22/20  1/23/20  \
# Country/Region
# Mainland China                   Anhui  31.8257  117.2264        1        9
# Mainland China                 Beijing  40.1824  116.4142       14       22
# Mainland China               Chongqing  30.0572  107.8740        6        9
# Mainland China                  Fujian  26.0789  117.9874        1        5
# Mainland China                   Gansu  36.0611  103.8343        0        2
# ...                                ...      ...       ...      ...      ...
# US                   Collin County, TX  33.1795  -96.4930        0        0
# US                Jefferson County, KY  38.1938  -85.6435        0        0
# US                Jefferson Parish, LA  29.6499  -90.1121        0        0
# US                   Shasta County, CA  40.7909 -121.8474        0        0
# US              Spartanburg County, SC  34.8606  -81.9535        0        0
#
# ...

# %%
df2 = df.groupby(level="Country/Region").sum()

# %%
df2.sum()[3:].plot(title='Global', figsize=(15,3))

# %%
countries = [
        'Mainland China',
        'Netherlands',
        'France',
        'US',
        'Spain',
        'UK',
        'Iran',
        'Germany',
        'Italy',
        # 'Global'
    ]
for country in countries:
    df2.loc[country][3:].plot(title=country)
    plt.show()
